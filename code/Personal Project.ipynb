# %%
# Configure Jupyter so figures appear in the notebook
# %matplotlib inline

# Configure Jupyter to display the assigned value after an assignment
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'

from modsim import *
# import everything from SymPy.
from sympy import *

#Import read_csv function from pandas
from pandas import read_csv

# %%
data = read_csv('POKEMON GO - Sheet1.csv', encoding = "ISO-8859-1", index_col = 'Pokemon')
# Out:
#                         IV Unnamed: 2
# Pokemon
# Bulbasaur              93%        NaN
# Charizard              87%        NaN
# Squirtle               82%        NaN
# Caterpie            89-93%        NaN
# Beedrill               89%        NaN
# Pidgeot                87%        NaN
# Raticate               87%        NaN
# Raticate (Alolan)      84%        NaN
# Fearow                 84%        NaN
# Arbok                  84%        NaN
# Raichu                 96%        NaN
# Sandshrew              96%        NaN
# Sandslash (Alolan)     91%        NaN
# Nidoran (f)            93%        NaN
# Nidoking               84%        NaN
# Clefable/Cleffa        82%        NaN
# Ninetales              83%        NaN
# Vulpix              82-84%        NaN
# Wigglytuff             84%        NaN
# Crobat(x2)             89%        NaN
# Vileplume              93%        NaN
# Bellossom              87%        NaN
# Parasect               84%        NaN
# Venomoth               88%        NaN
# Dugtrio                87%        NaN
# Diglett (Alolan)       89%        NaN
# Meowth              84-89%        NaN
# Persian (Alolan)       82%        NaN
# Golduck                82%        NaN
# Primeape               84%        NaN
# ...                    ...        ...
# Plusle              73-76%        NaN
# Minun                  76%        NaN
# Illumise               51%        NaN
# Roselia                89%        NaN
# Gulpin                 91%        NaN
# Sharpedo               82%        NaN
# Wailmer                82%        NaN
# Camerupt            82-84%        NaN
# Spoink              13-18%        NaN
# Spinda                 82%        NaN
# Cacturne               80%        NaN
# Altaria                82%        NaN
# Zangoose            56-58%        NaN
# Seviper                84%        NaN
# Solrock                69%        NaN
# Barboach               91%        NaN
# Crawdaunt              82%        NaN
# Baltoy                 69%        NaN
# Lileep                 73%        NaN
# Anorith                87%        NaN
# Feebas                 80%        NaN
# Castform               84%        NaN
# Banette                87%        NaN
# Duskull                89%        NaN
# Snorunt             84-87%        NaN
# Walrein                82%        NaN
# Luvdisc             76-80%        NaN
# Bagon                  96%        NaN
# Beldum                 53%        NaN
# Regirock               89%        NaN
#
# [191 rows x 2 columns]

# %%
plt.plot(data.index, data.IV)
